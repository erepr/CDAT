# %% [markdown]
# ### Generate Synthetic Data

# %%
import pandas as pd
import random
import numpy as np

# %%
N = 1000 # Number of rows

# Generate random data
data = {
    "Wellbeing": random.choices(["Generally Well", "Slightly below par", "Poor", "Very Poor", "Terrible"], k = N),
    "SiteDisease": random.choices(["Small Bowel", "Large Bowel", "Both/Mixed"], k = N),
    "BodyWeight": [random.randint(80, 120) for p in range(0, N)],
    "Appetite": random.choices(["Good", "Fair", "Poor"], k = N),
    "AvgTemp": [random.randint(36, 38) for p in range(0, N)],
    "Above100F": random.choices(["Yes", "No"], k = N),
    "Vomit": random.choices(["Yes", "No"], k = N),
    "LiquidStools": random.choices(["None", "1 to 4", "5 to 9", "10 to 19", "20 to 49"], k = N),
    "Diarrhea": random.choices(["Yes", "No"], k = N),
    "BowelMovements": random.choices(["Yes", "No"], k = N),
    "Arthritis": random.choices(["Yes", "No"], k = N),
    "Skin": random.choices(["Yes", "No"], k = N),
    "Eye": random.choices(["Yes", "No"], k = N),
    "AbdominalPain": random.choices(["None", "Mild", "Moderate", "Severe"], k = N),
    "Pain": random.choices(["< 1 Hour", "1 - 4 Hours", "5 Hours"], k = N),
    "PainAwake": random.choices(["Yes", "No"], k = N),
    "AbdominalMass": random.choices(["Absent", "Questionable", "Present"], k = N),
    "AbdominalTenderness": random.choices(["None", "Mild", "Moderate", "Severe"], k = N),
    "Fissure": random.choices(["Yes", "No"], k = N),
    "Blood": random.choices(["Yes", "No"], k = N),
    "Result": random.choices(["Very Well", "Fair to Good", "Poor", "Very Poor"], k = N),
}

df = pd.DataFrame(data)
  
df
# Out:
#               Wellbeing  SiteDisease  BodyWeight Appetite  AvgTemp Above100F  \
# 0              Terrible  Large Bowel         105     Fair       38        No
# 1              Terrible  Large Bowel          91     Poor       37       Yes
# 2                  Poor  Small Bowel          86     Fair       36       Yes
# 3              Terrible  Small Bowel         108     Fair       38       Yes
# 4             Very Poor   Both/Mixed         104     Fair       38        No
# ..                  ...          ...         ...      ...      ...       ...
# 995                Poor  Large Bowel         105     Fair       38        No
# 996  Slightly below par  Large Bowel          81     Poor       36       Yes
# 997                Poor  Large Bowel          98     Fair       36       Yes
# 998            Terrible  Small Bowel         108     Good       36       Yes
# 999           Very Poor  Large Bowel         110     Good       38        No
#
# ...

# %%
# Save Data
df.to_csv('data.csv', index=False)
